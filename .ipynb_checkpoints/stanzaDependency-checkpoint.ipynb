# %% [markdown]
# ### Exploring dependency tree parsing using stanza and also CoreNLP

# %%
import os
import re
import unicodedata
import numpy as np
import pandas as pd
import warnings
import nltk
import spacy
import stanza
import en_core_web_md
import matplotlib.pyplot as plt
import plotly.express as px
from nltk.stem import WordNetLemmatizer
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import euclidean_distances
from collections import defaultdict
from textblob import TextBlob
from nltk.tokenize import TreebankWordTokenizer
from nltk.tokenize import sent_tokenize
nltk.download('punkt')
word_token = TreebankWordTokenizer()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\peter\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Load up the speeches

# %%
# Load up the files
paths = ['./speeches/', './NYTimes/', './WSJ/'] 
list_of_files = []

dates = pd.read_csv('dateSpeeches.csv')
for path in paths:
    for root, dirs, files in os.walk(path):
        for file in files:
            if file.endswith('.txt'):
                list_of_files.append(os.path.join(root,file))

speeches = []
for file in list_of_files:
    with open(file, encoding='utf-8') as f:
        #print(file)
        text = f.read()
    f.close()
    speeches.append([text, file])

#clean out goofy unicode  space characters 
speeches = [(unicodedata.normalize("NFKD", speech[0]), speech[1]) for speech in speeches if len(speech)>0 ]

# remove [stuff] in between square brackets
def remove_bracket(text):
    return re.sub('(\[[^w]*\]\s)', '',text)
speeches = [(remove_bracket(speech[0]), speech[1]) for speech in speeches]

def get_source(text):
    regex = "[^./][a-zA-Z]+[^/]"
    string = re.findall(regex, str(text))[0]
    if string == 'speeches': string = 'oba'
    if string == 'NYTimes': string = 'nyt'
    return string.lower()

def get_date(text):
    regex = "([0-9]+[\-][0-9]+[\-][0-9]+)"
    return re.findall(regex, str(text))[0]

def get_filename(text):
    regex = "[-]([a-zA-Z]+)"
    return re.findall(regex, str(text))[0]

cols = ['text', 'filepath']
text_df = pd.DataFrame(speeches, columns=cols)
text_df['date'] = text_df['filepath'].apply(get_date)
text_df['date'] = pd.to_datetime(text_df['date'], format='%Y-%m-%d')
text_df['source'] = text_df['filepath'].apply(get_source)

text_df['sentences'] = text_df['text'].apply(sent_tokenize)
text_df['words'] = text_df['text'].apply(word_token.tokenize)
text_df['num_sents'] = text_df['sentences'].apply(len)
text_df['num_words'] = text_df['words'].apply(len)
text_df['word_set'] = text_df['words'].apply(set)
text_df['num_unique_words'] = text_df['word_set'].apply(len)
text_df.head(3)
# Out:
#                                                 text  \
# 0  On behalf of the great state of Illinois, cros...
# 1  Thank you....Thank you. What a -- What a wonde...
# 2  Hello, Chicago.\n\nIf there is anyone out ther...
#
#                                     filepath       date source  \
# 0        ./speeches/2004-07-28-DNCSpeech.txt 2004-07-28    oba
# 1  ./speeches/2008-06-04-ObamaNomination.txt 2008-06-04    oba
# 2     ./speeches/2008-11-05-ObamaElected.txt 2008-11-05    oba
#
#                                            sentences  \
# 0  [On behalf of the great state of Illinois, cro...
# 1  [Thank you....Thank you., What a -- What a won...
# 2  [Hello, Chicago., If there is anyone out there...
#
#                                                words  num_sents  num_words  \
# 0  [On, behalf, of, the, great, state, of, Illino...        107       2489
# 1  [Thank, you, ..., .Thank, you., What, a, --, W...        217       5920
# 2  [Hello, ,, Chicago., If, there, is, anyone, ou...         96       2266
#
#                                             word_set  num_unique_words
# 0  {following, sacrifice, moved, college., school...               892
# 1  {chance, lives, Paul, asks, South, reform, don...               937
# 2  {chance, lives, Those, connected, rejected, Jo...               756

# %% [markdown]
# <A HREF="https://textblob.readthedocs.io/en/latest/quickstart.html">TextBlob Quickstart guide</A>

# %%
text_df['TBsubjectivity']=[TextBlob(text).sentiment.subjectivity for text in text_df['text']]
text_df['TBpolarity']=[TextBlob(text).sentiment.polarity for text in text_df['text']]

# %% [markdown]
# <A HREF="https://plotly.com/python/plotly-express/">Plotly Express</A><BR><A HREF="https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf">Pandas cheat sheet</A>

# %% [markdown]
# <A HREF="https://universaldependencies.org/u/pos/">Universal POS tags</A>

# %% [markdown]
# <A HREF="https://en.wikipedia.org/wiki/Interjection">Wikipedia - Interjections</A>

# %% [markdown]
# <A HREF="https://pypi.org/project/NRCLex/">NRCLex</A>

# %% [markdown]
# ### Attempt 1. Stanza

# %% [markdown]
# ### <A HREF="https://stanfordnlp.github.io/stanza/getting_started.html">Stanza quickstart guide</A>

# %%
nlp = stanza.Pipeline(lang="en") # Initialize the default English pipeline
# Out:
# 2023-03-07 13:29:43 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# 2023-03-07 13:29:45 INFO: Loading these models for language: en (English):
# ============================
# | Processor    | Package   |
# ----------------------------
# | tokenize     | combined  |
# | pos          | combined  |
# | lemma        | combined  |
# | depparse     | combined  |
# | sentiment    | sstplus   |
# | constituency | wsj       |
# | ner          | ontonotes |
# ============================
#
# 2023-03-07 13:29:45 INFO: Use device: gpu
# 2023-03-07 13:29:45 INFO: Loading: tokenize
# 2023-03-07 13:29:48 INFO: Loading: pos
# 2023-03-07 13:29:48 INFO: Loading: lemma
# 2023-03-07 13:29:48 INFO: Loading: depparse
# 2023-03-07 13:29:48 INFO: Loading: sentiment
# 2023-03-07 13:29:49 INFO: Loading: constituency
# 2023-03-07 13:29:49 INFO: Loading: ner
# 2023-03-07 13:29:50 INFO: Done loading processors!

# %%
intxt=stanza.Document([], text=[sentence for sentence in text_df['sentences']][150][50])
out=nlp(intxt)
out
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "Mr.",
#       "lemma": "Mr.",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 3,
#       "deprel": "nsubj",
#       "start_char": 0,
#       "end_char": 3,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "Obama",
#       "lemma": "Obama",
#       "upos": "PROPN",
#       "xpos": "NNP",
#       "feats": "Number=Sing",
#       "head": 1,
#       "deprel": "flat",
#       "start_char": 4,
#       "end_char": 9,
#       "ner": "S-PERSON",
#       "multi_ner": [
#         "S-PERSON"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "won",
#       "lemma": "win",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 10,
#       "end_char": 13,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 4,
#       "text": "despite",
#       "lemma": "despite",
#       "upos": "SCONJ",
#       "xpos": "IN",
#       "head": 5,
#       "deprel": "mark",
#       "start_char": 14,
#       "end_char": 21,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 5,
#       "text": "losing",
#       "lemma": "lose",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "head": 3,
#       "deprel": "advcl",
#       "start_char": 22,
#       "end_char": 28,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 6,
#       "text": "some",
#       "lemma": "some",
#       "upos": "DET",
#       "xpos": "DT",
#       "head": 5,
#       "deprel": "obj",
#       "start_char": 29,
#       "end_char": 33,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 7,
#       "text": "of",
#       "lemma": "of",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 10,
#       "deprel": "case",
#       "start_char": 34,
#       "end_char": 36,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 8,
#       "text": "his",
#       "lemma": "he",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Gender=Masc|Number=Sing|Person=3|Poss=Yes|PronType=Prs",
#       "head": 10,
#       "deprel": "nmod:poss",
#       "start_char": 37,
#       "end_char": 40,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 9,
#       "text": "2008",
#       "lemma": "2008",
#       "upos": "NUM",
#       "xpos": "CD",
#       "feats": "NumForm=Digit|NumType=Card",
#       "head": 10,
#       "deprel": "compound",
#       "start_char": 41,
#       "end_char": 45,
#       "ner": "S-DATE",
#       "multi_ner": [
#         "S-DATE"
#       ]
#     },
#     {
#       "id": 10,
#       "text": "margins",
#       "lemma": "margin",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 6,
#       "deprel": "nmod",
#       "start_char": 46,
#       "end_char": 53,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 11,
#       "text": "among",
#       "lemma": "among",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 14,
#       "deprel": "case",
#       "start_char": 54,
#       "end_char": 59,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 12,
#       "text": "his",
#       "lemma": "he",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Gender=Masc|Number=Sing|Person=3|Poss=Yes|PronType=Prs",
#       "head": 14,
#       "deprel": "nmod:poss",
#       "start_char": 60,
#       "end_char": 63,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 13,
#       "text": "key",
#       "lemma": "key",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 14,
#       "deprel": "amod",
#       "start_char": 64,
#       "end_char": 67,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 14,
#       "text": "constituencies",
#       "lemma": "constituency",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 5,
#       "deprel": "obl",
#       "start_char": 68,
#       "end_char": 82,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 15,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 19,
#       "deprel": "punct",
#       "start_char": 82,
#       "end_char": 83,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 16,
#       "text": "including",
#       "lemma": "include",
#       "upos": "VERB",
#       "xpos": "VBG",
#       "feats": "VerbForm=Ger",
#       "head": 19,
#       "deprel": "case",
#       "start_char": 84,
#       "end_char": 93,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 17,
#       "text": "among",
#       "lemma": "among",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 19,
#       "deprel": "case",
#       "start_char": 94,
#       "end_char": 99,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 18,
#       "text": "younger",
#       "lemma": "young",
#       "upos": "ADJ",
#       "xpos": "JJR",
#       "feats": "Degree=Cmp",
#       "head": 19,
#       "deprel": "amod",
#       "start_char": 100,
#       "end_char": 107,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 19,
#       "text": "voters",
#       "lemma": "voter",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 5,
#       "deprel": "obl",
#       "start_char": 108,
#       "end_char": 114,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 20,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 21,
#       "deprel": "punct",
#       "start_char": 114,
#       "end_char": 115,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 21,
#       "text": "blacks",
#       "lemma": "black",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 19,
#       "deprel": "conj",
#       "start_char": 116,
#       "end_char": 122,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 22,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 24,
#       "deprel": "cc",
#       "start_char": 123,
#       "end_char": 126,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 23,
#       "text": "Jewish",
#       "lemma": "Jewish",
#       "upos": "ADJ",
#       "xpos": "JJ",
#       "feats": "Degree=Pos",
#       "head": 24,
#       "deprel": "amod",
#       "start_char": 127,
#       "end_char": 133,
#       "ner": "S-NORP",
#       "multi_ner": [
#         "S-NORP"
#       ]
#     },
#     {
#       "id": 24,
#       "text": "voters",
#       "lemma": "voter",
#       "upos": "NOUN",
#       "xpos": "NNS",
#       "feats": "Number=Plur",
#       "head": 19,
#       "deprel": "conj",
#       "start_char": 134,
#       "end_char": 140,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 25,
#       "text": ",",
#       "lemma": ",",
#       "upos": "PUNCT",
#       "xpos": ",",
#       "head": 28,
#       "deprel": "punct",
#       "start_char": 140,
#       "end_char": 141,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 26,
#       "text": "yet",
#       "lemma": "yet",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 28,
#       "deprel": "cc",
#       "start_char": 142,
#       "end_char": 145,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 27,
#       "text": "he",
#       "lemma": "he",
#       "upos": "PRON",
#       "xpos": "PRP",
#       "feats": "Case=Nom|Gender=Masc|Number=Sing|Person=3|PronType=Prs",
#       "head": 28,
#       "deprel": "nsubj",
#       "start_char": 146,
#       "end_char": 148,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 28,
#       "text": "appeared",
#       "lemma": "appear",
#       "upos": "VERB",
#       "xpos": "VBD",
#       "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#       "head": 3,
#       "deprel": "conj",
#       "start_char": 149,
#       "end_char": 157,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 29,
#       "text": "to",
#       "lemma": "to",
#       "upos": "PART",
#       "xpos": "TO",
#       "head": 30,
#       "deprel": "mark",
#       "start_char": 158,
#       "end_char": 160,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 30,
#       "text": "increase",
#       "lemma": "increase",
#       "upos": "VERB",
#       "xpos": "VB",
#       "feats": "VerbForm=Inf",
#       "head": 28,
#       "deprel": "xcomp",
#       "start_char": 161,
#       "end_char": 169,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 31,
#       "text": "his",
#       "lemma": "he",
#       "upos": "PRON",
#       "xpos": "PRP$",
#       "feats": "Gender=Masc|Number=Sing|Person=3|Poss=Yes|PronType=Prs",
#       "head": 32,
#       "deprel": "nmod:poss",
#       "start_char": 170,
#       "end_char": 173,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 32,
#       "text": "share",
#       "lemma": "share",
#       "upos": "NOUN",
#       "xpos": "NN",
#       "feats": "Number=Sing",
#       "head": 30,
#       "deprel": "obj",
#       "start_char": 174,
#       "end_char": 179,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 33,
#       "text": "among",
#       "lemma": "among",
#       "upos": "ADP",
#       "xpos": "IN",
#       "head": 34,
#       "deprel": "case",
#       "start_char": 180,
#       "end_char": 185,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 34,
#       "text": "Hispanics",
#       "lemma": "Hispanic",
#       "upos": "PROPN",
#       "xpos": "NNPS",
#       "feats": "Number=Plur",
#       "head": 32,
#       "deprel": "nmod",
#       "start_char": 186,
#       "end_char": 195,
#       "ner": "S-NORP",
#       "multi_ner": [
#         "S-NORP"
#       ]
#     },
#     {
#       "id": 35,
#       "text": "and",
#       "lemma": "and",
#       "upos": "CCONJ",
#       "xpos": "CC",
#       "head": 36,
#       "deprel": "cc",
#       "start_char": 196,
#       "end_char": 199,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 36,
#       "text": "Asians",
#       "lemma": "Asian",
#       "upos": "PROPN",
#       "xpos": "NNPS",
#       "feats": "Number=Plur",
#       "head": 34,
#       "deprel": "conj",
#       "start_char": 200,
#       "end_char": 206,
#       "ner": "S-NORP",
#       "multi_ner": [
#         "S-NORP"
#       ]
#     },
#     {
#       "id": 37,
#       "text": ".",
#       "lemma": ".",
#       "upos": "PUNCT",
#       "xpos": ".",
#       "head": 3,
#       "deprel": "punct",
#       "start_char": 206,
#       "end_char": 207,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     }
#   ]
# ]

# %%
print(*[f'id: {word.id}\tword: {word.text}\thead id: {word.head}\thead: {sent.words[word.head-1].text if word.head > 0 else "root"}\tdeprel: {word.deprel}' for sent in out.sentences for word in sent.words], sep='\n')
# Out:
# id: 1	word: Mr.	head id: 3	head: won	deprel: nsubj
# id: 2	word: Obama	head id: 1	head: Mr.	deprel: flat
# id: 3	word: won	head id: 0	head: root	deprel: root
# id: 4	word: despite	head id: 5	head: losing	deprel: mark
# id: 5	word: losing	head id: 3	head: won	deprel: advcl
# id: 6	word: some	head id: 5	head: losing	deprel: obj
# id: 7	word: of	head id: 10	head: margins	deprel: case
# id: 8	word: his	head id: 10	head: margins	deprel: nmod:poss
# id: 9	word: 2008	head id: 10	head: margins	deprel: compound
# id: 10	word: margins	head id: 6	head: some	deprel: nmod
# id: 11	word: among	head id: 14	head: constituencies	deprel: case
# id: 12	word: his	head id: 14	head: constituencies	deprel: nmod:poss
# id: 13	word: key	head id: 14	head: constituencies	deprel: amod
# id: 14	word: constituencies	head id: 5	head: losing	deprel: obl
# id: 15	word: ,	head id: 19	head: voters	deprel: punct
# id: 16	word: including	head id: 19	head: voters	deprel: case
# id: 17	word: among	head id: 19	head: voters	deprel: case
# id: 18	word: younger	head id: 19	head: voters	deprel: amod
# id: 19	word: voters	head id: 5	head: losing	deprel: obl
# id: 20	word: ,	head id: 21	head: blacks	deprel: punct
# id: 21	word: blacks	head id: 19	head: voters	deprel: conj
# id: 22	word: and	head id: 24	head: voters	deprel: cc
# id: 23	word: Jewish	head id: 24	head: voters	deprel: amod
# id: 24	word: voters	head id: 19	head: voters	deprel: conj
# id: 25	word: ,	head id: 28	head: appeared	deprel: punct
# id: 26	word: yet	head id: 28	head: appeared	deprel: cc
# id: 27	word: he	head id: 28	head: appeared	deprel: nsubj
# id: 28	word: appeared	head id: 3	head: won	deprel: conj
# id: 29	word: to	head id: 30	head: increase	deprel: mark
# id: 30	word: increase	head id: 28	head: appeared	deprel: xcomp
# id: 31	word: his	head id: 32	head: share	deprel: nmod:poss
# id: 32	word: share	head id: 30	head: increase	deprel: obj
# id: 33	word: among	head id: 34	head: Hispanics	deprel: case
# id: 34	word: Hispanics	head id: 32	head: share	deprel: nmod
# id: 35	word: and	head id: 36	head: Asians	deprel: cc
# id: 36	word: Asians	head id: 34	head: Hispanics	deprel: conj
# id: 37	word: .	head id: 3	head: won	deprel: punct

# %% [markdown]
# ### Attempt 2. Stanford's CoreNLP

# %%
# Using Stanford's CoreNLP parser with NLTK
# 1. Download CoreNLP from https://stanfordnlp.github.io/CoreNLP/download.html
# 2. make sure Java is installed, otherwise download and install Java - https://www.java.com/en/download/windows_manual.jsp
# 3. Unzip/extract CoreNLP zip file to a directory
# 4. Go to that directory and open a command terminal, and run the following command...
# 5. java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 15000
# 6. Now for graphviz if you want to view the parse trees, download from https://graphviz.org/download/ then install
# 6. Now, can run the following python code

# %%
# Can try this here, but may have to run from cmd terminal before continuing
# !java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 15000
# Out:
# 'java' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from graphviz import Source
from nltk.parse.corenlp import CoreNLPDependencyParser
import os

# %%
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

# %%
sdp = CoreNLPDependencyParser()
sentence = [sentence for sentence in text_df['sentences']][150][50]
result = list(sdp.raw_parse(sentence))
dep_tree_dot_repr = [parse for parse in result][0].to_dot()
source = Source(dep_tree_dot_repr, filename="dep_tree", format='png')
source.view()
# Opens in pop-under window... well isn't that nice!
# Out:
# 'dep_tree.png'

# %%
# Graph image doesn't get saved, need to re-run the code
source

# %% [markdown]
# ### Attempt 3. Spacy

# %% [markdown]
# <A HREF="https://stackoverflow.com/questions/64591644/how-to-get-height-of-dependency-tree-with-spacy">Followed this code</A> couldn't have done it without this!

# %%
# Try this just to the the height of the parse tree... using spacy
nlp = spacy.load("en_core_web_md")
doc = nlp(sentence)
depths = {}
def walk_tree(node, depth):
    depths[node.orth_] = depth
    if node.n_lefts + node.n_rights > 0:
        return [walk_tree(child, depth+1) for child in node.children]
[walk_tree(sent.root, 0) for sent in doc.sents]
print(depths)
print(max(depths.values()))
# Out:
# {'won': 0, 'Obama': 1, 'Mr.': 2, 'despite': 1, 'losing': 2, 'some': 3, 'of': 4, 'margins': 5, 'his': 4, '2008': 6, 'among': 3, 'constituencies': 4, 'key': 5, ',': 1, 'including': 5, 'voters': 9, 'younger': 8, 'blacks': 8, 'and': 5, 'Jewish': 10, 'yet': 1, 'appeared': 1, 'he': 2, 'increase': 2, 'to': 3, 'share': 3, 'Hispanics': 4, 'Asians': 5, '.': 2}
# 10

# %%
def walk_tree_depth(node, depth):
    if node.n_lefts + node.n_rights > 0:
        return max(walk_tree_depth(child, depth+1) for child in node.children )
    else:
        return depth
    
print([walk_tree_depth(sent.root, 0) for sent in doc.sents])
# Out:
# [10]

# %%
[walk_tree_depth(sent.root, 0) for sent in doc.sents][0]
# Out:
# 10

# %% [markdown]
# #### This makes the actual depth dataframe

# %%
# Make data frame of sentences and parse tree depth of each
def walk_tree_depth(node, depth):
    if node.n_lefts + node.n_rights > 0:
        return max(walk_tree_depth(child, depth+1) for child in node.children )
    else:
        return depth
    
tree_depth = pd.DataFrame(columns = ['date', 'source', 'sentence', 'depth'])
for i, speech in enumerate(text_df['sentences']):
    for j, sentence in enumerate(speech):
        doc = nlp(sentence)
        depth = [walk_tree_depth(sent.root, 0) for sent in doc.sents][0]
        tree_depth.loc[len(tree_depth)] = [text_df['date'].iloc[i], text_df['source'].iloc[i], sentence, depth]

# %%
tree_depth.head()
# Out:
#         date source                                           sentence  depth
# 0 2004-07-28    oba  On behalf of the great state of Illinois, cros...      8
# 1 2004-07-28    oba  Tonight is a particular honor for me because, ...      5
# 2 2004-07-28    oba  My father was a foreign student, born and rais...      7
# 3 2004-07-28    oba  He grew up herding goats, went to school in a ...      5
# 4 2004-07-28    oba  His father -- my grandfather -- was a cook, a ...      5

# %%
tree_depth.shape
# Out:
# (23670, 4)

# %%
#tree_depth.to_csv('sentence_depth.csv',index=False)
