# %% [markdown]
# ### Merge approval rating data into tidy data csv. Approval data start on 2009-01-21

# %% [markdown]
# <A HREF="https://news.gallup.com/poll/116479/barack-obama-presidential-job-approval.aspx">Gallup Approval Numbers</A><BR>

# %%
import os
import re
import unicodedata
import numpy as np
import pandas as pd
import warnings
import nltk
import en_core_web_md
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from nltk.stem import WordNetLemmatizer
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import euclidean_distances
from collections import defaultdict
from textblob import TextBlob
from nltk.tokenize import TreebankWordTokenizer
from nltk.tokenize import sent_tokenize

# %%
approval = pd.read_csv('./Data/genData/approvalData.csv')
approval['beg'] = pd.to_datetime(approval['beg'], format='%Y-%m-%d')
approval['end'] = pd.to_datetime(approval['end'], format='%Y-%m-%d')
approval.sort_values(by='beg', ignore_index=True, inplace=True)
approval.shape
# Out:
# (418, 5)

# %%
tidy_data = pd.read_csv('./Data/genData/tidy_data.csv')
tidy_data['date'] = pd.to_datetime(tidy_data['date'], format='%Y-%m-%d')
tidy_data.head(2)
# Out:
#         date source       ADJ       ADP      ADV       AUX     CCONJ  \
# 0 2008-06-04    nyt  0.064458  0.065088  0.06240  0.064962  0.064416
# 1 2008-06-04    oba  0.064649  0.064670  0.06444  0.064398  0.064471
#
#         DET      INTJ      NOUN  ...   sadness  surprise     trust  num_sents  \
# 0  0.063408  0.055598  0.064920  ...  0.075630  0.046218  0.130252         47
# 1  0.064638  0.054967  0.064503  ...  0.042017  0.048739  0.159664        217
#
#    num_words  num_unique_words     depth  TBsubjectivity TBpolarity  \
# 0       1459               620  7.276596        0.406976   0.135880
# 1       5856               939  5.986175        0.445383   0.167408
#
#    words_per_sentence
# 0           31.042553
# 1           26.986175
#
# [2 rows x 38 columns]

# %%
# Make an index of all dates in approval data range
idx = pd.date_range('2009-01-21', '2017-01-19')
# copy approval data to new df and use beg date for index
app = approval.set_index('beg')
# reindex using all dates and forward fill missing data
app = app.reindex(idx).ffill()
app.head(10)
# Out:
#                   end  approval  disapproval  no opinon
# 2009-01-21 2009-01-25      67.0         13.0       22.0
# 2009-01-22 2009-01-25      67.0         13.0       22.0
# 2009-01-23 2009-01-25      67.0         13.0       22.0
# 2009-01-24 2009-01-25      67.0         13.0       22.0
# 2009-01-25 2009-01-25      67.0         13.0       22.0
# 2009-01-26 2009-02-01      66.0         18.0       17.0
# 2009-01-27 2009-02-01      66.0         18.0       17.0
# 2009-01-28 2009-02-01      66.0         18.0       17.0
# 2009-01-29 2009-02-01      66.0         18.0       17.0
# 2009-01-30 2009-02-01      66.0         18.0       17.0

# %%
# make new date column which is a copy of the index
app['date'] = app.index
# drop the end row
app = app.drop('end', axis=1)
app
# Out:
#             approval  disapproval  no opinon       date
# 2009-01-21      67.0         13.0       22.0 2009-01-21
# 2009-01-22      67.0         13.0       22.0 2009-01-22
# 2009-01-23      67.0         13.0       22.0 2009-01-23
# 2009-01-24      67.0         13.0       22.0 2009-01-24
# 2009-01-25      67.0         13.0       22.0 2009-01-25
# ...              ...          ...        ...        ...
# 2017-01-15      57.0         39.0        4.0 2017-01-15
# 2017-01-16      59.0         37.0        4.0 2017-01-16
# 2017-01-17      59.0         37.0        4.0 2017-01-17
# 2017-01-18      59.0         37.0        4.0 2017-01-18
# 2017-01-19      59.0         37.0        4.0 2017-01-19
#
# [2921 rows x 4 columns]

# %%
# merge tidy_data and approval data
new = pd.merge(tidy_data, app, on='date',how='left')
# drop the rows with NaNs, before 2009-01-21, when approval data starts
new = new.dropna()
new
# Out:
#           date source       ADJ       ADP       ADV       AUX     CCONJ  \
# 12  2009-04-02    nyt  0.069702  0.070678  0.070569  0.069539  0.066883
# 13  2009-04-02    oba  0.069923  0.070734  0.070779  0.070644  0.070284
# 14  2009-04-02    wsj  0.071057  0.071814  0.067367  0.066373  0.071672
# 15  2009-04-15    nyt  0.069284  0.067063  0.070365  0.070545  0.068624
# 16  2009-04-15    oba  0.064179  0.064196  0.063894  0.064032  0.063980
# ..         ...    ...       ...       ...       ...       ...       ...
# 295 2016-11-09    oba  0.069479  0.069178  0.069730  0.069078  0.068376
# 296 2016-11-09    wsj  0.069166  0.068667  0.068939  0.068576  0.068078
# 297 2017-01-11    nyt  0.068761  0.069864  0.067920  0.065872  0.069811
# 298 2017-01-11    oba  0.066897  0.066921  0.066529  0.066823  0.066811
# 299 2017-01-11    wsj  0.072179  0.071380  0.071494  0.069095  0.071037
#
#           DET      INTJ      NOUN  ...  num_sents  num_words  \
# 12   0.070136  0.021192  0.070732  ...         46       1256
# 13   0.070509  0.000000  0.070554  ...         76       1491
# 14   0.071719  0.000000  0.071530  ...         62       1420
# 15   0.069224  0.000000  0.070605  ...         39       1128
# 16   0.064170  0.053538  0.064075  ...        283       7027
# ..        ...       ...       ...  ...        ...        ...
# 295  0.069429  0.042841  0.069329  ...         79       1303
# 296  0.069120  0.000000  0.069211  ...         61       1446
# 297  0.069916  0.041708  0.070074  ...         53       1275
# 298  0.066885  0.066676  0.066493  ...        231       5143
# 299  0.071608  0.000000  0.072293  ...         20        608
#
#      num_unique_words     depth  TBsubjectivity  TBpolarity  \
# 12                561  6.260870        0.357102    0.067402
# 13                642  5.328947        0.422101    0.098396
# 14                632  5.951613        0.296947    0.057422
# 15                538  6.846154        0.404185    0.087420
# 16               1735  5.908127        0.430164    0.090057
# ..                ...       ...             ...         ...
# 295               470  4.392405        0.490976    0.237315
# 296               623  6.098361        0.397283    0.114535
# 297               558  5.679245        0.454084    0.178910
# 298              1592  4.900433        0.500204    0.182039
# 299               325  7.300000        0.402340    0.126560
#
#      words_per_sentence  approval disapproval  no opinon
# 12            27.304348      62.0        28.0       10.0
# 13            19.618421      62.0        28.0       10.0
# 14            22.903226      62.0        28.0       10.0
# 15            28.923077      62.0        29.0        9.0
# 16            24.830389      62.0        29.0        9.0
# ..                  ...       ...         ...        ...
# 295           16.493671      57.0        41.0        3.0
# 296           23.704918      57.0        41.0        3.0
# 297           24.056604      57.0        39.0        4.0
# 298           22.264069      57.0        39.0        4.0
# 299           30.400000      57.0        39.0        4.0
#
# [288 rows x 41 columns]

# %%
# Save data
# new.to_csv('./Data/genData/tidy_data_approval.csv', index=False)

# %%
# Very little correlation between approval and anything else (except for disapproval)
new.corr(numeric_only=True)['approval']
# Out:
# ADJ                   0.012558
# ADP                   0.041829
# ADV                  -0.040080
# AUX                  -0.032651
# CCONJ                 0.055880
# DET                   0.042971
# INTJ                 -0.058567
# NOUN                  0.044863
# NUM                   0.009160
# PART                 -0.004145
# PRON                  0.018160
# PROPN                -0.058026
# PUNCT                 0.043187
# SCONJ                -0.095271
# SYM                   0.059188
# VERB                  0.039351
# PCA1                  0.001198
# PCA2                  0.097942
# anger                 0.029574
# anticipation         -0.040887
# disgust               0.063164
# fear                 -0.022048
# joy                  -0.026764
# negative              0.001365
# positive             -0.023861
# sadness               0.042273
# surprise              0.105901
# trust                -0.006237
# num_sents             0.051250
# num_words             0.034043
# num_unique_words      0.006119
# depth                -0.096575
# TBsubjectivity       -0.026014
# TBpolarity           -0.018659
# words_per_sentence   -0.062008
# approval              1.000000
# disapproval          -0.935156
# no opinon            -0.088144
# Name: approval, dtype: float64

# %% [markdown]
# <A HREF="https://plotly.com/python/plotly-express/">Plotly Express</A>

# %%
# "Do you approve or disapprove of the way Barack Obama is handling his job as president?"
fig = px.line(approval, 
             x="beg", 
             y="approval", 
             hover_name="approval",
             hover_data={'approval':':.3f'},
             title = 'Percent of polled Americans who approve of Barack Obama')
fig.show()
# Out:
# <div>                            <div id="974bbe9a-caed-4891-9483-fe970acce6bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("974bbe9a-caed-4891-9483-fe970acce6bd")) {                    Plotly.newPlot(                        "974bbe9a-caed-4891-9483-fe970acce6bd",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>beg=%{x}<br>approval=%{y:.3f}<extra></extra>","hovertext":[67.0,66.0,65.0,64.0,62.0,64.0,62.0,62.0,63.0,61.0,62.0,61.0,62.0,65.0,65.0,66.0,64.0,64.0,63.0,62.0,61.0,59.0,60.0,60.0,58.0,59.0,56.0,54.0,56.0,54.0,52.0,50.0,53.0,52.0,52.0,51.0,52.0,54.0,52.0,53.0,53.0,52.0,53.0,49.0,50.0,50.0,49.0,50.0,51.0,51.0,51.0,50.0,49.0,48.0,50.0,51.0,49.0,50.0,49.0,48.0,48.0,49.0,49.0,47.0,48.0,50.0,48.0,50.0,49.0,48.0,46.0,47.0,46.0,47.0,45.0,46.0,46.0,46.0,45.0,45.0,45.0,44.0,43.0,43.0,45.0,46.0,46.0,44.0,46.0,46.0,45.0,44.0,45.0,45.0,44.0,46.0,45.0,46.0,45.0,46.0,47.0,48.0,48.0,49.