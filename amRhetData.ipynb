# %% [markdown]
# <A HREF="https://github.com/pday2/teamBlauweKater">tBK GitHub Repository</A><BR>
# <A HREF="https://www.americanrhetoric.com/barackobamaspeeches.htm">American Rhetoric Barack Obama Speeches</A>

# %%
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup
import time # avoid swamping the americanrhetoric website
import os # to check if directory exists and create it if it doesn't
from datetime import datetime # to parse speech date

# %%
obamaURL = 'https://www.americanrhetoric.com/barackobamaspeeches.htm'
obamaPage = requests.get(obamaURL, headers={'user-agent': 'Mozilla/5.0'})
soup = BeautifulSoup(obamaPage.content, 'html.parser')

# %%
# From main Obama page, get all links to pages with speeches
llist = []

#              url from href                          urls are in <font>                          url cannot be None                    href url must start with speeches/...                    not contain PDFFiles
llist.append([ x.find('a',href=True)['href'] for x in soup.find_all('font', {'face':'Arial'}) if x.find('a',href=True) is not None and x.find('a',href=True)['href'].startswith('speeches/') and 'PDFFiles' not in x.find('a',href=True)['href']])

linklist = llist[0]

# %% [markdown]
# <A HREF="https://regexr.com/">RegExr: for testing regex</A><BR>
#     There is also <A HREF="https://regex101.com/">Regex101</A>

# %%
# Check if Data and associated folders exist for saving speech CSVs to.
# https://djangocentral.com/check-if-a-directory-exists-if-not-create-it/

MYDIRS = ["Data"]

# If folder doesn't exist, then create it.
for MYDIR in MYDIRS:
    CHECK_FOLDER = os.path.isdir(MYDIR)
    if CHECK_FOLDER:
        print(MYDIR, "folder already exists.")
    else:
        os.makedirs(MYDIR)
        print("created folder : ", MYDIR)
# Out:
# Data folder already exists.

# %% [markdown]
# <A HREF="https://beautiful-soup-4.readthedocs.io/en/latest/">Beautifulsoup documentation</A><BR>
# <A HREF="https://docs.python.org/3/library/re.html">Python regex documentation</A>

# %%
# 475 speeches at 3 seconds each is at least 16 minutes 
meta = []
for link in linklist:
    fulllink = 'https://www.americanrhetoric.com/' + link
    try:
        speechPage = requests.get(fulllink, headers={'user-agent': 'Mozilla/5.0'})
    except Exception as e:
        print(e, fulllink)

    pageHTML = BeautifulSoup(speechPage.content, 'html.parser')
    
    #-------------------- maybe remove meta data junk -----------------
    #get meta data - title
    title = re.sub("\r|\n|\t", "", str(pageHTML.title)[7:-8].strip())
    title = title.replace('American Rhetoric: ', '')
    title = title.replace('Barack Obama - ', '')
    print(title)
    
    #get meta data - delivered at
    # This is really ugly
    try:
        startText = '">delivered'
        start = str(pageHTML).find(startText)
        endText = '</font>'
        end = str(pageHTML).find(endText, start)
        delivered = str(pageHTML)[start+len(startText):end].replace('\n', '').replace('\r', '')
    except:
        try:
            startText = '">Delivered'
            start = str(pageHTML).find(startText)
            endText = '</font>'
            end = str(pageHTML).find(endText, start)
            delivered = str(pageHTML)[start+len(startText):end].replace('\n', '').replace('\r', '')
        except:
            print("Rats!")
    #-------------------- maybe remove meta data junk -----------------
    
    #Speech paragraphs are wrapped in <font face="Verdana" size="2">...</font>
    speech = pageHTML.find_all("font", {'face':'Verdana'})

    text = []
    for i in range(len(speech)):
        # Match anything inside an html tag (<>): \<.*?\>
        # could also try [n.get_text(strip=True) for n in speech] which leaves \r and \n
        tmp = re.sub("\r|\n|\t|\<.*?\>", "", str(speech[i]))
        # toss empty paragraphs and the last Book/CDs credit
        if (len(tmp) > 0) and not tmp.startswith('Book/CDs'):
            text.append(tmp)
    
    string = ' '.join(text)
    
    df = pd.DataFrame(text)
    filename = 'Data/' + re.sub("(\w+[\/])", "", link[:-4]) + '.csv'
    textfilename = 'Data/' + re.sub("(\w+[\/])", "", link[:-4]) + '.txt'
    df.to_csv(filename, encoding='utf-8', header=False, index=False)
    # Write a text file
    text_file = open(textfilename, 'w')
    text_file.write(string)
    text_file.close()
    
    temp=[]
    temp.append(title)
    temp.append(delivered[0])
    temp.append(delivered[1:])
    temp.append(filename)
    temp.append(fulllink)
    meta.append(temp)
    time.sleep(3) #be kind!
# Out:
# Speech on the Iraq War at Federal Plaza, Chicago
# Barack Obama 2004 Democratic National Convention Keynote Address - American Rhetoric
# Senate Floor Speech on the Ohio Electoral Vote Counting Process
# Knox College Commencement Address
# Senate Floor Speech on Rosa Parks (transcript-audio-video)
# Senate Floor Speech on the Patriot Act
# Senate Floor Speech on the Passing of Coretta Scott King
# Senate Floor Speech on Voting Rights Act Renewal
# Barack Obama Announces Presidental Exploratory Committee
# Announcement of Presidential Candidacy
# Selma Voting Rights March Commemoration at Brown Chapel
# Senate Floor Speech Supporting Iraq Federalism Amendment
# Senate Floor Speech on the War in Iraq After 4 Years
# Senate Floor Speech on Immigration
# Address at The Woodrow Wilson International Center for Scholars
# Speech at the Jefferson-Jackson Dinner
# Iowa Caucus Victory Speech
# New Hampshire Primary Concession Speech
# Address at Ebenezer Baptist Church
# Victory Speech in South Carolina
# A More Perfect Union (Philadelphia Speech)
# Democratic Nomination Victory Speech
# Iraq War Policy Speech at the Woodrow Wilson Center
# Address to the People of Berlin
# Barack Obama -- Democratic Presidential Nomination Acceptance Speech
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Senate Floor Speech in Support of Wall Street Bailout Bill
# President-Elect Victory Speech
# Opening Remarks During First Press Conference as President-Elect
# Barack Obama: Taped Remarks to Global Climate Summit
# Announces Economic Team
# Announces Office of Management and Budget Director and Deputy Director
# Announces Office of Management and Budget Director and Deputy Director
# Announces Leaders of Economic Recovery Advisory Board
# Announces Security Team
# Announces Commerce Secretary-Designate
# Press Conference with Economic Team (01-05-09)
# Speech on the Economy at George Mason University
# Announcement of Key Leaders of the National Intelligence Community
# Pre-Inauguration Address at the Lincoln Memorial
# First Presidential Inaugural Address
# Barack Obama: First Presidential Weekly Address (01-24-09)
# Al-Arabiya Television Interview
# Remarks on Executive Compensation
# First Presidential Prime Time Press Conference
# Speech at the D.C. Abraham Lincoln Bicentennial Celebration Event (transcript-audio-video)
# 102nd Abraham Lincoln Association Banquet Address (transcript-audio-video)
# Speech Before a Joint Session of Congress (02-24-09)
# On Ending the War in Iraq at Camp Lajeune
# Speech to the Hispanic Chamber of Commerce on American Education
# G20 London Global Economic Recovery Summit Remarks and Press Conference
# Speech at Strasbourg Town Hall
# Speech in Prague
# Speech to the Turkish Parliament
# Speech to Troops Serving in Iraq (transcript-audio-video)
# Speech at Georgetown University on Economic Vision
# First Address at the Central Intelligence Agency
# Holocaust Days of Remembrance Ceremony Speech
# White House Correspondents' Dinner Speech 2009
# Barack Obama: Commencement Address at Arizona State University (transcript-audio-video)
# Joint Press Conference with Prime Minister Benjamin Netanyahu
# Commencement Speech at the University of Notre Dame
# Speech on National Security at the National Archives
# Address on Securing U.S. Cyber Infrastructure (transcript-audio-video)
# Speech at Cairo University
# Speech at Buchenwald Concentration Camp
# 65th Anniversary of D-Day Address - American Rhetoric
# Speech to the American Medical Association
# On the Uprising in Iran
# Third Press Conference on Iran, Clean Energy, Health Care
# Speech at the New Economic School in Moscow
# Address to the Parliament of Ghana
# Nomination of Regina Benjamin for Surgeon General of the United States
# American Graduation Initiative Speech in Michigan
# Eulogy for Ted Kennedy
# Back to School Speech to America's Schoolchildren (transcript-audio-video)
# Eulogy for Walter Cronkite (transcript-audio-video)
# Speech to a Joint Session of Congress on Health Care Reform (9 September 2009)
# 9/11 Pentagon Memorial Speech
# Speech to the United Nations General Assembly
# Speech at Fort Hood Memorial Service
# Shanghai Town Hall With Future Chinese Leaders
# Speech at West Point on Troop Increase in Afghanistan
# Speech at the Kennedy Center Reception 2009
# Speech on Job Creation and Economic Growth at the Brookings Institute
# Nobel Prize for Peace Lecture and Speech Transcript Audio Video
# Speech at the Copenhagen Climate Change Conference (Morning Plenary Session)
# Barack Obama Press Statement on Terrorist Attempt on Northwest Airlines Flight 253
# Barack Obama Speech on Attempted Terrorist Attack in Detroit (text-audio-video)
# Press Conference on National Security Review Following Christmas Day Attempted Terrorist Attack on Flight 253
# Strengthening Intelligence and Aviation Security 01-10-10)
# Speech Proposing Financial Crisis Responsibility Fee
# Martin Luther King Remembrance Speech
# Town Hall Speech at Lorain County Community College
# Speech Commemorating 65th Anniversary of Auschwitz and Birkenau Liberation
# 2010 State of the Union Address
# Open Discussion at Republican Party House Issues Conference
# Speech on the 2010 Budget Sent to Congress
# 2010 National Prayer Breakfast Speech
# Unannounced Press Briefing Appearence on Jobs and Heath Care
# Townhall Speech and Q and A in Henderson Nevada (complete transcript video)
# Call for Congress to Vote on Health Care Reform Legislation
# Weekly Address on No Child Left Behind Act
# Health Care Speech at George Mason University
# Speech to the House Democratic Caucus on Passing Health Care Reform Bill
# Speech to the Nation on Passage of New Health Care Reform Bill
# Signing of Health Care Reform Bill Into Law
# Speech to Troops in Afghanistan
# Speech on Energy Security at Andrews Air Force Base
# Press Conference on START Treaty Signing
# Remarks on the Mining Tragedy in West Virginia and Justice Stevens Retirement
# NASA and Space Exploration in the 21st Century
# Speech on Reforming Wall Street
# Speech at the Memorial Service for Upper Big Branch Miners
# Eulogy for Dorothy Height
# Commencement Address at the University of Michigan
# White House Correspondents' Dinner Speech 2010
# Nomination of Elena Kagan for U.S. Supreme Court Justice
# Barack Obama -- Commencement Speech at the U.S. Military Academy 2010
# Major Press Conference on the Gulf Oil Spill
# Grande Isle Briefing on the Gulf Oil Spill Disaster
# Speech on the Economy at Carnegie Mellon University
# Commencement Speech at Kalamazoo Central High School
# Speech on United Nations Security Council Sanctions on Iran
# Speech Before Military at Pensacola
# Oval Office Speech to the Nation on BP Oil Spill Disaster
# Speech to the American Nurses Association
# 2010 Father's Day Address
# Remarks on the Resignation of Gen. McChrystal and Nomination of Gen. Petraeus in Afghanistan
# American University Speech on Comprehensive Immigration Reform
# Address at the Memorial Service for Robert Byrd
# Speech on Signing the Wall Street Reform and Consumer Protection Act
# Speech On Education Reform at the Urban League Centennial (text-audio-video)
# Speech on Ending Combat in Iraq
# Speech on Religious Tolerance at Iftar Dinner
# Oval Office Speech on End of Operation Iraqi Freedom Mission
# 9/11 Pentagon Memorial Address
# Speech at the 65th Session of the United Nations General Assembly
# Press Conference Following 2010 Congressional Elections
# Mumbai Business Summit Speech
# Speech to Joint Session of the Indian Parliament
# Speech to Students at the University of Indonesia
# Address on Awarding Medal of Honor to Staff Sgt. Salvatore Giunta
# Speech to Troops at Bagram Air Base 2010
# Barack Obama and William Jefferson Clinton - Press Conference on Tax Cuts
# Speech at the Together We Thrive Tucson Memorial Service (transcript-audio-video)
# 2011 State of the Union Address (text-audio-video)
# Address on the Political Transition in Egypt (text-audio-video)
# Prayer Breakfast Speech 2011
# Speech to the US Chamber of Commerce (transcript-audio-video)
# Northern Michigan University Speech on National Wireless Initiative  (transcript-audio-video)
# Address on the Revolutionary Changes in Egypt (transcript-audio-video)
# Speech on Libya (transcript-audio-video)
# Address on Libya (transcript-audio-video)
# Address on Ltd. Military Action in Libya  (transcript-audio-video)
# Speech to the People of Rio de Janeiro  (transcript-audio-video)
# Barack Obama -  Address to the People of Chile on Latin America (transcript-audio-video)
# Address to the Nation on Libya 28 March 2011 (transcript-audio-video)
# Barack Obama -  Address on American Energy Security at Georgetown (transcript-audio-video)
# Speech on Fiscal Policy at George Washington University (transcript-audio-video)
# Speech Declaring 2012 Presidential Candidacy(transcript-audio-video)
# Barack Obama: Remarks on Birth Certificate (transcript-audio-video)
# Onsite Remarks in Alabama Following Tornado Devestation  (transcript-audio-video)
# Commencement Address at Miami Dade College  (transcript-audio-video)
# White House Correspondents' Dinner Speech 2011
# Speech on the Death of Osama Bin Laden (transcript-audio-video)
# Speech to Troops at Fort Campbell, Kentucky (transcript-audio-video)
# Commencement Address at Booker T. Washington High School (transcript-audio-video)
# Speech on American Diplomacy in the Middle East and North Africa (transcript-audio-video)
# Speech to the Intelligence Community at CIA Headquarters (transcript-audio-video)
# Barack Obama and Benjamin Netanyahu - Joint Remarks to the Press on 20 May 2011 (transcript-audio-video)
# Address a American-Israeli PAC Policy Conference (transcript-audio-video)
# Address to the British Parliament (transcript-audio-video)
# Address at the Memorial for Joplin Tornado Victims (transcript-audio-video)
# On New Defense Personnel (transcript-audio-video)
# Address to the Nation on Afghanistan War Troop Reduction (transcript-audio-video)
# Address at Carnegie Mellon's National Robotic Center (transcript-audio-video)
# Press Conference on Congressional Action to Promote Job Growth (transcript-audio-video)
# Speech to the Nation on the Dangers of Default (transcript-audio-video)
# Speech on the Debt Compromise (transcript-audio-video)
# Speech on the Approved Debt Compromise (transcript-audio-video)
# Barack Obama -- Address to the American Legion Conference in Minnesota (transcript-audio-video)
# Joint Session of Congress Speech on Jobs (transcript-audio-video)
# Rose Garden Speech on Debt Reduction Plan and Economic Growth (transcript-audio-video)
# Speech on United Nations Meeting on Libya (transcript-audio-video)
# Speech to the UN General Assembly on Palestine Statehood (transcript-audio-video)
# Speech at the Martin Luther King Jr. Memorial Dedication (transcript-audio-video)
# Speech on the Death of Muammar Qaddfi (transcript-audio-video)
# Speech on Ending the War in Iraq Responsibly (transcript-audio-video)
# Speech to the Australian Parliament (transcript-audio-video)
# Speech at the Tribal Nations Conference (transcript-audio-video)
# Speech on the Economy at Osawatomie High School (transcript-audio-video)
# Weekly Address Honoring Military Service in Iraq (transcript-audio-video)
# Speech at the Pentagon on Military Strategy Changes (transcript-audio-video)
# 2012 State of the Union Address (text-audio-video)
# Speech on Housing at Falls Church Virginia (transcript-video)
# Barack Obama Address on Veterans Job Corps (transcript--video)
# Speech Toasting Iraq War Veterans (transcript-audio-video)
# Speech to the American Israel Public Affairs Committee 2012 (transcript-audio-video)
# Address at Hamkuk University
# Address on Oil and Gas Subsidies (transcript-audio-video)
# Speech at an Associate Press Luncheon (transcript-audio-video)
# National Holocaust Memorial Museum Address
# White House Correspondents' Dinner Speech 2012
# Barnard College Commencement Address (transcript-audio-video)
# Shimon Peres Presidential Medal of Freedom Remarks
# On the USSC Ruling on the Affordable Care Act (transcript-audio-video)
# Speech on the Shooting Tragedy in Aurora Colorado (transcript-audio-video)
# Speech to the 113th Convention of the Veterans of Foreign Wars (transcript-audio-video)
# Second Presidential Nomination Acceptance Speech (transcript-audio-video)
# Rose Garden Speech on Benghazi Attacks (text-audio-video)
# Address at the Tranfer Ceremony for Benghazi Victims (transcript-audio-video)
# Speech on Human Tafficking at the 2012 Cinton Global Initiative - American Rhetoric
# Speech to the United Nations General Assembly 67th Session (transcript-audio-video)
# Barack Obama and Mitt Romney - First Presidential Candidate Debate - American Rhetoric
# Barack Obama and Mitt Romney - Second Presidential Debate - American Rhetoric
# Barack Obama and Mitt Romney - Third Presidential Debate (transcript-audio-video)
# Barack Obama -  Remarks on Hurricane Sandy Following FEMA Meeting (transcript-audio-video)
# Speech at the Red Cross on Hurricane Sandy (transcript-audio-video)
# Barack Obama: 2012 Presidential Election Victory Speech (transcript-audio-video)
# Presidential Endorsement of Hillary Clinton
# Statement on the Orlando Florida Shootings
# Counter ISIL Meeting Briefing
# United State of Women Summit Address
# Statement to the Community of Orlando, Florida
# Remarks Following USSC Ruling in US v Texas
# Barack Obama Address to the Parliament of Canada (text-audio-video)
# Press Conference Following 2016 NATO Summit
# Dallas Police Memorial Address
# 2016 Democratic National Convention Address
# ISIL Press Conference
# Baton Rouge Flooding Press Statement
# Press Conference After G20 Summit
# Address to the People of Laos
# Post ASEAN Press Conference
# Address on the 15-Year Anniversary of 9/11
# Statement on the Explosions in New York and New Jersey
# Final United Nations Address
# Address at the National Museum of African-American History Dedication
# Shimon Peres Memorial Ceremony Address
# Address on the 2016 Presidential Election Outcome
# Remarks on First Meeting with President-Elect Trump
# Press Conference Post 2016 Presidential Election
# Address to the People of Greece
# Angela Merkel Joint Press Conference 2016
# Young Leaders of the Americas Initiative Speech
# Peru Press Conference
# Kennedy Center Honors Reception 2016 Address
# On the Administration's Approach to Counter-Terrorism
# Final Presidential Press Conference of 2016
# Address at Pearl Harbor
# Farewell Address to Armed Forces
# VOX Live Interview
# Presidential Farewell Address
# Joe Biden Medal of Freedom Presentation Address
# Final Weekly Address
# Chicago Cubs MLB 2017 Champions White House Visit Address
# Final Presidential Press Conference
# Farewell Address to Staff at Andrews Air Force Base

# %%
# Just checking probably delete this once we're happy with the data
text1 = '25 October 2005, Washington, D.C.'
text2 = '4 April 1997'
text1.split(',')[0]
text2.split(',')[1:]
date1 = datetime.strptime(text1.split(',')[0], '%d %B %Y')
print(date1)
# Out:
# 2005-10-25 00:00:00

# %%
date1.year
# Out:
# 2005

# %%
date1.month
# Out:
# 10

# %%
date1.day
# Out:
# 25

# %%
dfmeta = pd.DataFrame(meta)
dfmeta.to_csv('metaData.csv', encoding='utf-8', header=False, index=False)

# %%
df = pd.DataFrame(linklist)
df.to_csv('linklist.csv', encoding='utf-8', header=False, index=False)

# %%
# I Just went through date_title.csv manually and fixed the speech dates
# American Rhetoric is a mess, the code is a mess and inconsistent
datetitle = pd.read_csv('date_title.csv')

# %%
datetitle=datetitle.dropna() 
datetitle = datetitle.reset_index(drop = True)

# %%
datetitle['url'] = ['Data/'+re.sub("(\w+[\/])", "", link[:-4])+'.txt' for link in datetitle['url']]

# %%
datetitle['date'] = [ datetime.strptime(day, '%d %b %Y') for day in datetitle['date']]

# %%
datetitle.to_csv('datetitle.csv', index=False)

# %%
approval = pd.read_csv('approvalData.csv', parse_dates=['beg', 'end'])

# %%
# Sort for merge_asof
# Sort datetitle by date
datetitle.sort_values(by=['date']);
datetitle.dropna();
# Sort approval by beg
approval.sort_values(by=['beg']);
approval.dropna();

# %% [markdown]
# <A HREF="https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf">Pandas cheat sheet</A>

# %%
dateTitleAppr = pd.merge_asof(datetitle.sort_values('date'), approval.sort_values('beg'), left_on="date", right_on="beg").dropna()

# %%
dateTitleAppr.to_csv('dateTitleAppr.csv', index=False)
